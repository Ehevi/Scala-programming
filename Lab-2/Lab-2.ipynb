// %% [markdown]
// # Laboratorium 2.

// %% [markdown]
// ## 1. Przygotowanie klasy referencyjnej w Javie

// %% [markdown]
// ![lab2-1.png](attachment:lab2-1.png)

// %% [markdown]
// ## 2. Definicja klasy w Scali

// %% [markdown]
// #### Zadanie
// Przepisać definicję klasy `Person` z Javy do Scali (do pliku `lab2.scala`)
